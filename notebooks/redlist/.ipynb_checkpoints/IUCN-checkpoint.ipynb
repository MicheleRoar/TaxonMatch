# %%
import pandas as pd
import taxonmatch as txm

# %%
# Suppress warnings from the requests library
logging.getLogger("requests").setLevel(logging.ERROR)

# %%
iucn_code = txm.find_dataset_id_by_name("iucn")
# Out:
# Title: The IUCN Red List of Threatened Species, ID: 19491596-35ae-4a91-9a98-85cf505f1bd3

# %%
iucn_dataset = txm.download_gbif_taxonomy(source = iucn_code)
# Out:
# GBIF backbone taxonomy data already downloaded.
# Processing samples...
# Done.

# %%
ncbi_dataset = txm.download_ncbi_taxonomy()
# Out:
# NCBI taxonomy data already downloaded.
# Processing samples...
# Done.

# %%
iucn_arthropoda = iucn_dataset[0][iucn_dataset[0].phylum == "Arthropoda"]

# %%
df_with_iucn_status = add_iucn_status_column(iucn_arthropoda)
# Out:
# Progress: 100.00%

# %%
df_with_iucn_status
# Out:
#           taxonID                             datasetID  parentNameUsageID  \
# 56234    11441042  19491596-35ae-4a91-9a98-85cf505f1bd3            1926040
# 56236    11840699  19491596-35ae-4a91-9a98-85cf505f1bd3            1926040
# 56237    11778839  19491596-35ae-4a91-9a98-85cf505f1bd3            1926040
# 79584     5791081  19491596-35ae-4a91-9a98-85cf505f1bd3            4644568
# 81296     5791055  19491596-35ae-4a91-9a98-85cf505f1bd3            5791054
# ...           ...                                   ...                ...
# 7636077   4449486  19491596-35ae-4a91-9a98-85cf505f1bd3            4449483
# 7645391  10723220  19491596-35ae-4a91-9a98-85cf505f1bd3            4406444
# 7646407   4449458  19491596-35ae-4a91-9a98-85cf505f1bd3            4405178
# 7676646  11370760  19491596-35ae-4a91-9a98-85cf505f1bd3            1424939
# 7676650  11373505  19491596-35ae-4a91-9a98-85cf505f1bd3            1424939
#
#         acceptedNameUsageID                  canonicalName   taxonRank  \
# 56234                             Durbaniella clarki phaea  subspecies
# 56236                            Durbaniella clarki clarki  subspecies
# 56237                        Durbaniella clarki jenniferae  subspecies
# 79584                         Sundathelphusa leschenaultii     species
# 81296                           Cylindrothelphusa steniops     species
# ...                     ...                            ...         ...
# 7636077                                Leipaspis lauricola     species
# 7645391                                 Nemozoma breviatum     species
# 7646407                                Grynocharis oblonga     species
# 7676646                              Rhionaeschna serrania     species
# 7676650                               Rhionaeschna itataia     species
#
#         taxonomicStatus   kingdom      phylum         class        order  \
# 56234          accepted  Animalia  Arthropoda       Insecta  Lepidoptera
# 56236          accepted  Animalia  Arthropoda       Insecta  Lepidoptera
# 56237          accepted  Animalia  Arthropoda       Insecta  Lepidoptera
# 79584          accepted  Animalia  Arthropoda  Malacostraca     Decapoda
# 81296          accepted  Animalia  Arthropoda  Malacostraca     Decapoda
# ...                 ...       ...         ...           ...          ...
# 7636077        accepted  Animalia  Arthropoda       Insecta   Coleoptera
# 7645391        accepted  Animalia  Arthropoda       Insecta   Coleoptera
# 7646407        accepted  Animalia  Arthropoda       Insecta   Coleoptera
# 7676646        accepted  Animalia  Arthropoda       Insecta      Odonata
# 7676650        accepted  Animalia  Arthropoda       Insecta      Odonata
#
#                  family              genus  \
# 56234        Lycaenidae        Durbaniella
# 56236        Lycaenidae        Durbaniella
# 56237        Lycaenidae        Durbaniella
# 79584    Gecarcinucidae     Sundathelphusa
# 81296    Gecarcinucidae  Cylindrothelphusa
# ...                 ...                ...
# 7636077   Trogossitidae          Leipaspis
# 7645391   Trogossitidae           Nemozoma
# 7646407   Trogossitidae        Grynocharis
# 7676646       Aeshnidae       Rhionaeschna
# 7676650       Aeshnidae       Rhionaeschna
#
#                                              gbif_taxonomy gbif_taxonomy_ids  \
# 56234    arthropoda;insecta;lepidoptera;lycaenidae;durb...          11441042
# 56236    arthropoda;insecta;lepidoptera;lycaenidae;durb...          11840699
# 56237    arthropoda;insecta;lepidoptera;lycaenidae;durb...          11778839
# 79584    arthropoda;malacostraca;decapoda;gecarcinucida...           5791081
# 81296    arthropoda;malacostraca;decapoda;gecarcinucida...   5791054;5791055
# ...                                                    ...               ...
# 7636077  arthropoda;insecta;coleoptera;trogossitidae;le...           4449486
# 7645391  arthropoda;insecta;coleoptera;trogossitidae;ne...          10723220
# 7646407  arthropoda;insecta;coleoptera;trogossitidae;gr...           4449458
# 7676646  arthropoda;insecta;odonata;aeshnidae;rhionaesc...          11370760
# 7676650  arthropoda;insecta;odonata;aeshnidae;rhionaesc...          11373505
#
#         iucnRedListCategory
# 56234         LEAST_CONCERN
# 56236         LEAST_CONCERN
# 56237         LEAST_CONCERN
# 79584        DATA_DEFICIENT
# 81296         LEAST_CONCERN
# ...                     ...
# 7636077          VULNERABLE
# 7645391      DATA_DEFICIENT
# 7646407       LEAST_CONCERN
# 7676646       LEAST_CONCERN
# 7676650       LEAST_CONCERN
#
# [995 rows x 16 columns]

# %%
def load_a3cat_dataframe(ncbi_filterd):
    url = 'https://a3cat.unil.ch'
    
    # Fare la richiesta HTTP al sito web
    response = requests.get(url)
    response.raise_for_status()  # Assicurarsi che la richiesta abbia avuto successo

    # Fare il parsing del contenuto HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Trovare l'elemento con l'ID specificato
    version_tag = soup.find(id="header-version")
    
    if version_tag:
        # Estrarre la versione
        version = version_tag.text.strip()
        # Estrarre la data dalla versione
        date = version.split('v.')[1]
        # Generare il link del file
        download_link = f"{url}/data/a3cat/{date}.tsv"
        
        # Scaricare il file e caricare i dati in un DataFrame pandas
        df = pd.read_csv(download_link, sep='\t')
        a3cat = ncbi_filtered[ncbi_filtered.ncbi_id.astype(int).isin(df.TaxId)]
        return a3cat
    else:
        print("Last version not found, please download the dataset manually")
        return None

# %%
# Utilizzo della funzione
a3cat = load_a3cat_dataframe()

# %%
a3cat
# Out:
#          ncbi_id                                 ncbi_lineage_names  \
# 5338        6661  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 5343        6669  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 5352        6678  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 5360        6687  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 5362        6689  cellular organisms;Eukaryota;Opisthokonta;Meta...
# ...          ...                                                ...
# 2563734  3098083  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 2565541  3102772  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 2568333  3109984  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 2572787  3116773  cellular organisms;Eukaryota;Opisthokonta;Meta...
# 2582797  3133883  cellular organisms;Eukaryota;Opisthokonta;Meta...
#
#                                           ncbi_lineage_ids  \
# 5338     131567;2759;33154;33208;6072;33213;33317;12067...
# 5343     131567;2759;33154;33208;6072;33213;33317;12067...
# 5352     131567;2759;33154;33208;6072;33213;33317;12067...
# 5360     131567;2759;33154;33208;6072;33213;33317;12067...
# 5362     131567;2759;33154;33208;6072;33213;33317;12067...
# ...                                                    ...
# 2563734  131567;2759;33154;33208;6072;33213;33317;12067...
# 2565541  131567;2759;33154;33208;6072;33213;33317;12067...
# 2568333  131567;2759;33154;33208;6072;33213;33317;12067...
# 2572787  131567;2759;33154;33208;6072;33213;33317;12067...
# 2582797  131567;2759;33154;33208;6072;33213;33317;12067...
#
#            ncbi_canonicalName ncbi_rank  \
# 5338      Artemia franciscana   species
# 5343            Daphnia pulex   species
# 5352          Balanus nubilus   species
# 5360          Penaeus monodon   species
# 5362         Penaeus vannamei   species
# ...                       ...       ...
# 2563734     Chrysina gloriosa   species
# 2565541   Druceiella hillmani   species
# 2568333  Polylopha cassiicola   species
# 2572787      Rosalia funebris   species
# 2582797       Campoplex nolae   species
#
#                                         ncbi_lineage_ranks  \
# 5338     no rank;superkingdom;clade;kingdom;clade;clade...
# 5343     no rank;superkingdom;clade;kingdom;clade;clade...
# 5352     no rank;superkingdom;clade;kingdom;clade;clade...
# 5360     no rank;superkingdom;clade;kingdom;clade;clade...
# 5362     no rank;superkingdom;clade;kingdom;clade;clade...
# ...                                                    ...
# 2563734  no rank;superkingdom;clade;kingdom;clade;clade...
# 2565541  no rank;superkingdom;clade;kingdom;clade;clade...
# 2568333  no rank;superkingdom;clade;kingdom;clade;clade...
# 2572787  no rank;superkingdom;clade;kingdom;clade;clade...
# 2582797  no rank;superkingdom;clade;kingdom;clade;clade...
#
#                                         ncbi_target_string
# 5338     arthropoda;branchiopoda;anostraca;artemiidae;a...
# 5343     arthropoda;branchiopoda;diplostraca;daphniidae...
# 5352     arthropoda;thecostraca;balanomorpha;balanidae;...
# 5360     arthropoda;malacostraca;decapoda;penaeidae;pen...
# 5362     arthropoda;malacostraca;decapoda;penaeidae;pen...
# ...                                                    ...
# 2563734  arthropoda;insecta;coleoptera;scarabaeidae;chr...
# 2565541  arthropoda;insecta;lepidoptera;hepialidae;druc...
# 2568333  arthropoda;insecta;lepidoptera;tortricidae;pol...
# 2572787  arthropoda;insecta;coleoptera;cerambycidae;ros...
# 2582797  arthropoda;insecta;hymenoptera;ichneumonidae;c...
#
# [3744 rows x 7 columns]
